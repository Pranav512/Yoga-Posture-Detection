# %% [markdown]
# pip install --upgrade pip

# %% [markdown]
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib

# %%
import tensorflow as tf
import os

# %%
#Avoid OOM errors by setting gpu memory consumption growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
import cv2
import imghdr
import numpy as np
from matplotlib import pyplot as plt

# %%
data_dir = 'data'
image_exts = ['jpeg','jpg', 'bmp', 'png']

# %%
img = cv2.imread(os.path.join('data', '1', 'WIN_20230321_11_51_45_Pro.jpg'))
print(img.shape)
print(img)
# Out:
# (720, 1280, 3)
# [[[124 145 146]
#   [126 147 148]
#   [129 151 149]
#   ...
#   [ 67  71  95]
#   [ 63  70  90]
#   [ 58  65  85]]
#
#  [[124 145 146]
#   [127 149 147]
#   [129 151 149]
#   ...
#   [ 66  70  94]
#   [ 63  70  90]
#   [ 59  66  86]]
#
#  [[124 146 144]
#   [127 149 147]
#   [130 152 150]
#   ...
#   [ 65  69  93]
#   [ 64  71  91]
#   [ 61  68  88]]
#
#  ...
#
#  [[153 164 156]
#   [153 164 156]
#   [153 164 156]
#   ...
#   [184 192 182]
#   [183 193 181]
#   [184 194 182]]
#
#  [[152 165 157]
#   [152 165 157]
#   [153 164 156]
#   ...
#   [182 191 181]
#   [181 190 180]
#   [182 191 181]]
#
#  [[152 165 157]
#   [151 164 156]
#   [153 164 156]
#   ...
#   [179 188 178]
#   [178 187 177]
#   [178 187 177]]]

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        image = cv2.imread(image_path)

        mask = np.zeros(image.shape[:2], np.uint8)

        rectangle = (256, 256, 100, 100)

        bgdModel = np.zeros((1, 65), np.float64)
        fgdModel = np.zeros((1, 65), np.float64)
        cv2.grabCut(image, mask, rectangle, bgdModel, fgdModel, 5, cv2.GC_INIT_WITH_RECT)

        mask_binary = np.where((mask == 2) | (mask == 0), 0, 1).astype('uint8')

        segmented_image = image * np.expand_dims(mask_binary, axis=-1)
        
        image = segmented_image

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 480 files belonging to 6 classes.

# %%
data
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
batch[0]
# Out:
# array([[[[143.     , 148.     , 126.     ],
#          [139.90625, 144.90625, 124.90625],
#          [139.     , 143.     , 128.     ],
#          ...,
#          [187.90625, 194.90625, 186.90625],
#          [187.09375, 199.09375, 187.09375],
#          [189.     , 198.     , 181.     ]],
#
#         [[136.84375, 145.5625 , 124.5625 ],
#          [136.28125, 144.71875, 126.     ],
#          [137.28125, 145.71875, 129.     ],
#          ...,
#          [193.     , 200.     , 192.     ],
#          [185.     , 197.     , 185.     ],
#          [189.     , 197.     , 182.     ]],
#
#         [[135.53125, 144.53125, 125.53125],
#          [137.53125, 146.53125, 129.53125],
#          [139.53125, 147.53125, 132.53125],
#          ...,
#          [191.     , 198.     , 190.     ],
#          [187.53125, 199.53125, 187.53125],
#          [189.     , 197.     , 182.     ]],
#
#         ...,
#
#         [[155.46875, 168.46875, 159.46875],
#          [160.     , 173.     , 164.     ],
#          [156.46875, 172.46875, 162.46875],
#          ...,
#          [176.53125, 191.53125, 184.53125],
#          [179.0625 , 194.0625 , 187.0625 ],
#          [175.46875, 190.46875, 183.46875]],
#
#         [[157.28125, 169.71875, 161.     ],
#          [158.71875, 171.71875, 162.71875],
#          [158.     , 174.     , 164.     ],
#          ...,
#          [176.28125, 191.28125, 184.28125],
#          [176.     , 191.     , 184.     ],
#          [176.28125, 191.28125, 184.28125]],
#
#         [[157.09375, 168.09375, 160.09375],
#          [159.09375, 172.09375, 163.09375],
#          [157.90625, 173.90625, 163.90625],
#          ...,
#          [180.     , 193.     , 186.     ],
#          [178.09375, 191.09375, 184.09375],
#          [180.90625, 193.90625, 186.90625]]],
#
#
#        [[[142.     , 145.     , 136.     ],
#          [137.09375, 145.09375, 134.09375],
#          [139.     , 147.     , 134.     ],
#          ...,
#          [155.1875 , 148.1875 , 140.1875 ],
#          [158.     , 147.     , 141.     ],
#          [152.     , 148.     , 139.     ]],
#
#         [[142.     , 145.     , 134.5625 ],
#          [136.     , 144.     , 131.     ],
#          [138.     , 146.     , 133.     ],
#          ...,
#          [152.28125, 149.28125, 140.28125],
#          [156.     , 148.4375 , 140.71875],
#          [153.     , 149.     , 140.     ]],
#
#         [[139.     , 145.     , 133.     ],
#          [137.     , 145.     , 132.     ],
#          [137.     , 148.     , 134.     ],
#          ...,
#          [148.40625, 150.9375 , 139.9375 ],
#          [154.53125, 151.53125, 142.53125],
#          [152.     , 149.     , 140.     ]],
#
#         ...,
#
#         [[145.     , 158.     , 151.     ],
#          [143.     , 156.     , 146.     ],
#          [142.53125, 155.53125, 146.53125],
#          ...,
#          [176.40625, 185.40625, 180.40625],
#          [183.125  , 192.125  , 187.125  ],
#          [179.53125, 190.53125, 184.53125]],
#
#         [[142.71875, 155.71875, 148.71875],
#          [144.84375, 157.84375, 147.84375],
#          [146.71875, 159.71875, 150.71875],
#          ...,
#          [182.     , 188.     , 184.     ],
#          [180.71875, 189.71875, 184.71875],
#          [179.40625, 188.6875 , 182.84375]],
#
#         [[141.     , 154.     , 147.     ],
#          [146.8125 , 159.8125 , 149.8125 ],
#          [146.90625, 159.90625, 150.90625],
#          ...,
#          [182.     , 188.     , 184.     ],
#          [179.46875, 189.46875, 181.46875],
#          [187.625  , 197.625  , 189.625  ]]],
#
#
#        [[[140.09375, 151.09375, 137.09375],
#          [146.1875 , 153.1875 , 137.1875 ],
#          [150.90625, 152.90625, 138.90625],
#          ...,
#          [152.90625, 153.90625, 148.90625],
#          [155.1875 , 150.1875 , 147.1875 ],
#          [151.1875 , 152.1875 , 147.1875 ]],
#
#         [[140.15625, 149.     , 135.71875],
#          [141.28125, 149.71875, 133.     ],
#          [150.     , 154.     , 140.     ],
#          ...,
#          [155.71875, 156.71875, 151.71875],
#          [156.71875, 152.4375 , 149.4375 ],
#          [152.71875, 153.71875, 148.71875]],
#
#         [[142.     , 150.     , 135.     ],
#          [142.     , 151.     , 134.     ],
#          [146.46875, 152.46875, 138.46875],
#          ...,
#          [152.9375 , 153.9375 , 147.9375 ],
#          [156.53125, 155.53125, 150.53125],
#          [151.     , 152.     , 146.     ]],
#
#         ...,
#
#         [[137.875  , 153.34375, 144.9375 ],
#          [133.     , 156.0625 , 143.53125],
#          [133.34375, 157.9375 , 149.40625],
#          ...,
#          [169.     , 181.     , 179.     ],
#          [170.     , 185.     , 182.     ],
#          [175.875  , 187.875  , 185.875  ]],
#
#         [[147.15625, 161.     , 150.71875],
#          [139.125  , 159.84375, 145.6875 ],
#          [141.     , 161.     , 152.     ],
#          ...,
#          [172.     , 184.     , 182.     ],
#          [168.     , 183.     , 180.     ],
#          [178.15625, 190.15625, 188.15625]],
#
#         [[142.09375, 160.09375, 148.09375],
#          [142.8125 , 164.8125 , 151.8125 ],
#          [144.1875 , 163.1875 , 157.1875 ],
#          ...,
#          [176.375  , 188.375  , 186.375  ],
#          [173.     , 188.     , 185.     ],
#          [177.1875 , 189.1875 , 187.1875 ]]],
#
#
#        ...,
#
#
#        [[[138.71875, 149.8125 , 134.     ],
#          [140.90625, 154.90625, 129.90625],
#          [144.     , 151.     , 133.1875 ],
#          ...,
#          [159.09375, 155.09375, 152.09375],
#          [151.1875 , 150.1875 , 145.1875 ],
#          [148.90625, 149.90625, 133.71875]],
#
#         [[143.71875, 151.28125, 135.     ],
#          [142.4375 , 153.28125, 128.     ],
#          [142.5625 , 151.     , 132.28125],
#          ...,
#          [158.     , 155.     , 148.5625 ],
#          [153.     , 152.     , 147.     ],
#          [150.     , 151.71875, 137.71875]],
#
#         [[147.     , 149.53125, 133.9375 ],
#          [144.53125, 152.53125, 128.53125],
#          [144.53125, 153.53125, 132.53125],
#          ...,
#          [155.46875, 155.46875, 145.46875],
#          [152.0625 , 151.0625 , 146.0625 ],
#          [155.     , 157.     , 146.     ]],
#
#         ...,
#
#         [[141.9375 , 158.9375 , 148.9375 ],
#          [146.53125, 162.53125, 151.53125],
#          [143.     , 160.     , 154.     ],
#          ...,
#          [165.53125, 180.53125, 177.53125],
#          [167.46875, 178.46875, 174.46875],
#          [173.53125, 182.53125, 179.53125]],
#
#         [[141.     , 158.84375, 148.5625 ],
#          [145.     , 161.5625 , 150.28125],
#          [143.71875, 161.28125, 155.28125],
#          ...,
#          [171.84375, 186.84375, 183.84375],
#          [170.71875, 183.5625 , 179.28125],
#          [171.28125, 184.125  , 179.84375]],
#
#         [[142.09375, 162.09375, 151.09375],
#          [143.28125, 161.28125, 149.28125],
#          [145.     , 164.     , 158.     ],
#          ...,
#          [174.09375, 189.09375, 186.09375],
#          [170.09375, 187.09375, 181.09375],
#          [174.     , 191.     , 185.     ]]],
#
#
#        [[[126.     , 130.     , 105.     ],
#          [122.     , 135.     , 118.     ],
#          [124.09375, 135.09375, 121.09375],
#          ...,
#          [ 88.90625,  72.90625,  46.90625],
#          [ 80.46875,  87.65625,  56.65625],
#          [129.8125 , 147.09375, 139.     ]],
#
#         [[129.71875, 131.71875, 107.71875],
#          [124.4375 , 134.     , 117.     ],
#          [126.4375 , 135.28125, 120.5625 ],
#          ...,
#          [ 88.71875,  72.71875,  46.71875],
#          [ 82.34375,  83.90625,  53.46875],
#          [137.03125, 150.15625, 140.15625]],
#
#         [[129.46875, 131.46875, 109.46875],
#          [126.46875, 133.46875, 115.46875],
#          [127.53125, 134.53125, 118.53125],
#          ...,
#          [ 93.53125,  77.     ,  49.9375 ],
#          [ 92.40625,  87.875  ,  58.34375],
#          [143.125  , 147.     , 134.46875]],
#
#         ...,
#
#         [[166.46875, 181.0625 , 170.53125],
#          [167.875  , 185.875  , 173.875  ],
#          [167.9375 , 183.9375 , 172.9375 ],
#          ...,
#          [171.0625 , 183.0625 , 179.0625 ],
#          [178.125  , 190.125  , 186.125  ],
#          [177.53125, 189.53125, 185.53125]],
#
#         [[175.125  , 181.     , 172.71875],
#          [174.     , 186.71875, 176.15625],
#          [172.     , 185.28125, 174.4375 ],
#          ...,
#          [169.     , 184.     , 179.     ],
#          [170.28125, 185.28125, 180.28125],
#          [172.     , 187.     , 182.     ]],
#
#         [[180.09375, 181.09375, 173.09375],
#          [175.09375, 184.90625, 173.90625],
#          [173.09375, 185.09375, 173.09375],
#          ...,
#          [174.     , 189.     , 184.     ],
#          [170.     , 185.     , 180.     ],
#          [170.71875, 185.71875, 180.71875]]],
#
#
#        [[[133.     , 143.1875 , 134.09375],
#          [132.28125, 146.28125, 133.28125],
#          [133.09375, 147.09375, 130.09375],
#          ...,
#          [ 97.09375,  75.09375,  25.09375],
#          [ 99.09375,  82.09375,  38.09375],
#          [ 95.     ,  77.     ,  41.     ]],
#
#         [[132.28125, 140.84375, 130.40625],
#          [132.     , 144.5625 , 130.84375],
#          [136.71875, 148.28125, 132.     ],
#          ...,
#          [ 95.     ,  73.     ,  25.4375 ],
#          [ 97.71875,  78.71875,  35.71875],
#          [ 99.15625,  77.71875,  40.71875]],
#
#         [[133.46875, 139.46875, 129.46875],
#          [135.46875, 146.46875, 132.46875],
#          [137.53125, 146.53125, 129.53125],
#          ...,
#          [ 93.46875,  68.9375 ,  26.53125],
#          [ 96.46875,  75.46875,  32.46875],
#          [101.     ,  79.     ,  42.     ]],
#
#         ...,
#
#         [[166.53125, 179.53125, 169.53125],
#          [161.     , 177.     , 166.     ],
#          [163.     , 179.     , 168.     ],
#          ...,
#          [173.71875, 181.375  , 174.3125 ],
#          [150.875  , 158.     , 152.53125],
#          [134.5625 , 141.6875 , 137.15625]],
#
#         [[164.     , 178.     , 165.     ],
#          [162.5625 , 178.5625 , 167.5625 ],
#          [163.5625 , 179.5625 , 168.5625 ],
#          ...,
#          [134.125  , 132.5625 , 127.     ],
#          [134.71875, 131.15625, 125.875  ],
#          [130.875  , 131.875  , 126.59375]],
#
#         [[162.     , 176.     , 163.     ],
#          [164.90625, 180.90625, 167.90625],
#          [169.     , 185.     , 174.     ],
#          ...,
#          [134.     , 131.     , 122.     ],
#          [134.09375, 130.09375, 121.09375],
#          [129.     , 129.     , 121.     ]]]], dtype=float32)

# %%
batch[1]
# Out:
# array([5, 0, 0, 4, 2, 0, 3, 3, 3, 5, 1, 3, 3, 2, 1, 4, 1, 3, 1, 0, 4, 2,
#        1, 5, 2, 4, 3, 2, 3, 0, 3, 4])

# %% [markdown]
# ##
# 0: Mountain
# 1: Tree
# 2: Lotus
# 3: Lunge
# 4: Plank
# 5: DownDog

# %%
fig, ax = plt.subplots(ncols=5, figsize=(20,20))
for idx, img in enumerate(batch[0][:5]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
data = data.map(lambda x,y: (x/255, y))
# Out:
# WARNING:tensorflow:From E:\College\Project\BackEnd\prolib\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
batch = data.as_numpy_iterator().next()

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)+1

# %%
print(len(data))
print(train_size)
print(val_size)
print(test_size)
# Out:
# 15
# 10
# 3
# 2

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
from tensorflow.keras import datasets, layers, models

# %%
model = models.Sequential()

# %%
model.add(layers.Conv2D(32, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(layers.MaxPooling2D())

model.add(layers.Conv2D(64, (3,3), 1, activation='relu'))
model.add(layers.MaxPooling2D())

model.add(layers.Conv2D(128, (3,3), 1, activation='relu'))
model.add(layers.MaxPooling2D())

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(6, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 115200)            0
#
#  dense (Dense)               (None, 128)               14745728
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 14,839,750
# Trainable params: 14,839,750
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(train, epochs=50, validation_data=val)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 25s 2s/step - loss: 2.5774 - accuracy: 0.2719 - val_loss: 1.0944 - val_accuracy: 0.8958
# Epoch 2/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.5630 - accuracy: 0.8219 - val_loss: 0.0562 - val_accuracy: 0.9792
# Epoch 3/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0684 - accuracy: 0.9906 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 4/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0224 - accuracy: 0.9906 - val_loss: 7.8449e-04 - val_accuracy: 1.0000
# Epoch 5/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0211 - accuracy: 0.9875 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 6/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0123 - accuracy: 0.9937 - val_loss: 1.3352e-04 - val_accuracy: 1.0000
# Epoch 7/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.1038e-05 - val_accuracy: 1.0000
# Epoch 8/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.7124e-06 - val_accuracy: 1.0000
# Epoch 9/50
# 10/10 [==============================] - 22s 2s/step - loss: 4.1828e-04 - accuracy: 1.0000 - val_loss: 7.2022e-08 - val_accuracy: 1.0000
# Epoch 10/50
# 10/10 [==============================] - 22s 2s/step - loss: 9.9192e-04 - accuracy: 1.0000 - val_loss: 2.3221e-07 - val_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - 22s 2s/step - loss: 4.4484e-04 - accuracy: 1.0000 - val_loss: 4.3462e-08 - val_accuracy: 1.0000
# Epoch 12/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 4.3462e-08 - val_accuracy: 1.0000
# Epoch 13/50
# 10/10 [==============================] - 22s 2s/step - loss: 3.6501e-04 - accuracy: 1.0000 - val_loss: 1.9247e-07 - val_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 23s 2s/step - loss: 3.4333e-04 - accuracy: 1.0000 - val_loss: 1.2790e-07 - val_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 23s 2s/step - loss: 6.5834e-04 - accuracy: 1.0000 - val_loss: 2.4835e-09 - val_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.2418e-09 - val_accuracy: 1.0000
# Epoch 17/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 5.8645e-06 - val_accuracy: 1.0000
# Epoch 18/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 3.7646e-05 - val_accuracy: 1.0000
# Epoch 19/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0084 - accuracy: 0.9969 - val_loss: 1.9512e-05 - val_accuracy: 1.0000
# Epoch 20/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0156 - accuracy: 0.9906 - val_loss: 7.5959e-06 - val_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.5985e-05 - val_accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0039 - accuracy: 0.9969 - val_loss: 3.3409e-05 - val_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.2418e-08 - val_accuracy: 1.0000
# Epoch 24/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 5.0912e-08 - val_accuracy: 1.0000
# Epoch 25/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0041 - accuracy: 0.9969 - val_loss: 5.7643e-05 - val_accuracy: 1.0000
# Epoch 26/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.6909e-06 - val_accuracy: 1.0000
# Epoch 27/50
# 10/10 [==============================] - 22s 2s/step - loss: 2.9077e-04 - accuracy: 1.0000 - val_loss: 6.1963e-07 - val_accuracy: 1.0000
# Epoch 28/50
# 10/10 [==============================] - 23s 2s/step - loss: 1.6495e-04 - accuracy: 1.0000 - val_loss: 2.2352e-08 - val_accuracy: 1.0000
# Epoch 29/50
# 10/10 [==============================] - 22s 2s/step - loss: 1.5775e-04 - accuracy: 1.0000 - val_loss: 1.2418e-08 - val_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - 22s 2s/step - loss: 1.6753e-04 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 31/50
# 10/10 [==============================] - 22s 2s/step - loss: 2.1611e-04 - accuracy: 1.0000 - val_loss: 6.2088e-09 - val_accuracy: 1.0000
# Epoch 32/50
# 10/10 [==============================] - 22s 2s/step - loss: 3.6026e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 33/50
# 10/10 [==============================] - 22s 2s/step - loss: 1.1100e-04 - accuracy: 1.0000 - val_loss: 1.2418e-09 - val_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - 22s 2s/step - loss: 6.3549e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - 22s 2s/step - loss: 3.7525e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 36/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0068 - accuracy: 0.9969 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0065 - accuracy: 0.9969 - val_loss: 1.2418e-09 - val_accuracy: 1.0000
# Epoch 38/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0058 - accuracy: 0.9969 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - 22s 2s/step - loss: 1.4994e-04 - accuracy: 1.0000 - val_loss: 4.9671e-09 - val_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 6.7956e-06 - val_accuracy: 1.0000
# Epoch 41/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0027 - accuracy: 0.9969 - val_loss: 6.4075e-07 - val_accuracy: 1.0000
# Epoch 42/50
# 10/10 [==============================] - 22s 2s/step - loss: 1.0744e-04 - accuracy: 1.0000 - val_loss: 5.3396e-08 - val_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - 22s 2s/step - loss: 5.6380e-04 - accuracy: 1.0000 - val_loss: 1.2418e-09 - val_accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 22s 2s/step - loss: 2.7236e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 22s 2s/step - loss: 6.1051e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 22s 2s/step - loss: 8.9187e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 22s 2s/step - loss: 2.8552e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 22s 2s/step - loss: 2.7658e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
model.evaluate(test)
# Out:
# 2/2 [==============================] - 2s 340ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# [0.0, 1.0]

# %%
img = cv2.imread('img6.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
ypred = model.predict(np.expand_dims(resize/255, 0))
ypred
# Out:
# 1/1 [==============================] - 0s 37ms/step
# array([[8.7871421e-24, 2.5435207e-35, 1.0000000e+00, 2.8938477e-24,
#         6.7416219e-26, 5.6235523e-29]], dtype=float32)

# %%
yclass = [np.argmax(element) for element in ypred]

# %%
if ypred[0][yclass] < 0.8:
    print('Try Again')
else:
    print(yclass)
# Out:
# [2]

# %%
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','trainedmodel1.h5'))
